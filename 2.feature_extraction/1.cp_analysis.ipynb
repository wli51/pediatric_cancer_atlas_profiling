# %% [markdown]
# # Perform segmentation and feature extraction using CellProfiler

# %% [markdown]
# ## Import libraries

# %%
import pathlib
import pprint

import sys

sys.path.append("../utils")
import cp_parallel

# %% [markdown]
# ## Set paths and variables

# %%
# set the run type for the parallelization
run_name = "analysis"

# set path for CellProfiler pipeline
path_to_pipeline = pathlib.Path("./analysis.cppipe").resolve(strict=True)

# set main output dir for all plates if it doesn't exist
output_dir = pathlib.Path("./sqlite_outputs")
output_dir.mkdir(exist_ok=True)

# directory where loaddata CSVs are located within the folder
loaddata_dir = pathlib.Path("./loaddata_csvs").resolve(strict=True)

# Extract plate names and include as list
plate_names = [
    file.stem.split('_')[0] 
    for file in loaddata_dir.glob("*.csv")
]

# Print the number of plates and their names
print(f"Total number of plates: {len(plate_names)}")
print("Plate Names:")
for name in plate_names:
    print(name)
# Out:
# Total number of plates: 6
# Plate Names:
# BR00143979
# BR00143976
# BR00143980
# BR00143978
# BR00143977
# BR00143981

# %% [markdown]
# ## Create dictionary to process data

# %%
# create plate info dictionary with all parts of the CellProfiler CLI command to run in parallel
plate_info_dictionary = {
    name: {
        "path_to_loaddata": next(loaddata_dir.glob(f"{name}*.csv"), None),
        "path_to_output": output_dir / name,
        "path_to_pipeline": path_to_pipeline,
    }
    for name in plate_names if next(loaddata_dir.glob(f"{name}*.csv"), None)
}

# view the dictionary to assess that all info is added correctly
pprint.pprint(plate_info_dictionary, indent=4)
# Out:
# {   'BR00143976': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143976_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143976'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')},
#     'BR00143977': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143977_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143977'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')},
#     'BR00143978': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143978_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143978'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')},
#     'BR00143979': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143979_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143979'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')},
#     'BR00143980': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143980_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143980'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')},
#     'BR00143981': {   'path_to_loaddata': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/loaddata_csvs/BR00143981_concatenated_with_illum.csv'),
#                       'path_to_output': PosixPath('sqlite_outputs/BR00143981'),
#                       'path_to_pipeline': PosixPath('/home/jenna/pediatric_cancer_atlas_profiling/2.feature_extraction/analysis.cppipe')}}

# %% [markdown]
# ## Perform segmentation and feature extraction (analysis)
#
# Note: This code cell was not ran as we prefer to perform CellProfiler processing tasks via `sh` file (bash script) which is more stable.

# %%
cp_parallel.run_cellprofiler_parallel(
    plate_info_dictionary=plate_info_dictionary, run_name=run_name
)
